# %%
import pandas as pd

# Load data
df = pd.read_csv('data/spotify_plays.csv')

# Basic exploration
print(df.head())
print(df.info())
print(df.columns.tolist())

# Check for unique values in key columns
print("Unique users:", df['user_id'].nunique())
print("Unique tracks:", df['track_id'].nunique())
print("Unique artists:", df['artist_name'].nunique())
print("Unique countries:", df['country'].nunique())
# Out:
#    play_id user_id  user_age user_country subscription_tier track_id  \
# 0        1   U0178        43           UK              Free   T00072
# 1        2   U0462        52        India           Premium   T00080
# 2        3   U0140        36      Germany           Premium   T00025
# 3        4   U0419        24        Japan           Premium   T00088
# 4        5   U0501        31          USA           Premium   T00022
#
#      track_name artist_name    album_name  album_release_year  ...  \
# 0  Track A018-4   Artist 18  Album A018-2                2020  ...
# 1  Track A020-4   Artist 20  Album A020-2                2018  ...
# 2  Track A007-1    Artist 7  Album A007-1                2021  ...
# 3  Track A022-4   Artist 22  Album A022-2                2019  ...
# 4  Track A006-2    Artist 6  Album A006-1                2018  ...
#
#   device_type platform os_version           city  state_province  country  \
# 0      Mobile  Android       12.0     Manchester             ENG       UK
# 1      Mobile      iOS       17.5         Mumbai              MH    India
# 2     Desktop    macOS       13.5        Hamburg              HH  Germany
# 3     Desktop    macOS       13.5          Tokyo              TK    Japan
# 4      Mobile      iOS       17.5  San Francisco              CA      USA
#
#   play_seconds completed  skips            timestamp
# 0          157         0      1  2024-10-24 18:28:27
# 1          309         1      0  2024-10-18 10:18:39
# 2          198         1      0  2024-10-28 06:17:25
# 3          236         1      0  2024-10-21 04:14:40
# 4           71         0      0  2024-10-28 10:44:10
#
# [5 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   play_id             3000 non-null   int64
#  1   user_id             3000 non-null   object
#  2   user_age            3000 non-null   int64
#  3   user_country        3000 non-null   object
#  4   subscription_tier   3000 non-null   object
#  5   track_id            3000 non-null   object
#  6   track_name          3000 non-null   object
#  7   artist_name         3000 non-null   object
#  8   album_name          3000 non-null   object
#  9   album_release_year  3000 non-null   int64
#  10  genre_primary       3000 non-null   object
#  11  genre_secondary     3000 non-null   object
#  12  device_type         3000 non-null   object
#  13  platform            3000 non-null   object
#  14  os_version          3000 non-null   float64
#  15  city                3000 non-null   object
#  16  state_province      3000 non-null   object
#  17  country             3000 non-null   object
#  18  play_seconds        3000 non-null   int64
#  19  completed           3000 non-null   int64
#  20  skips               3000 non-null   int64
#  21  timestamp           3000 non-null   object
# dtypes: float64(1), int64(6), object(15)
# memory usage: 515.8+ KB
# None
# ['play_id', 'user_id', 'user_age', 'user_country', 'subscription_tier', 'track_id', 'track_name', 'artist_name', 'album_name', 'album_release_year', 'genre_primary', 'genre_secondary', 'device_type', 'platform', 'os_version', 'city', 'state_province', 'country', 'play_seconds', 'completed', 'skips', 'timestamp']
# Unique users: 593
# Unique tracks: 96
# Unique artists: 24
# Unique countries: 7

# %%
df.columns
# Out:
# Index(['play_id', 'user_id', 'user_age', 'user_country', 'subscription_tier',
#        'track_id', 'track_name', 'artist_name', 'album_name',
#        'album_release_year', 'genre_primary', 'genre_secondary', 'device_type',
#        'platform', 'os_version', 'city', 'state_province', 'country',
#        'play_seconds', 'completed', 'skips', 'timestamp'],
#       dtype='object')

# %%
df['country'].unique()
# Out:
# array(['UK', 'India', 'Germany', 'Japan', 'USA', 'Canada', 'Brazil'],
#       dtype=object)
